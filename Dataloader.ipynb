# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 32.68 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 547 kB 51.8 MB/s
# ...
#      |████████████████████████████████| 8.4 MB 54.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 138 kB 54.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# Classfication dataset

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Bear --type_csv train
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#    [ERROR] | Missing the class-descriptions.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...101%, 0 MB, 63507 KB/s, 0 seconds passed
# ...

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Person --type_csv train --limit 1500
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Person
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 906091 online images for train.
#     [INFO] | Limiting to 1500 images.
#     [INFO] | Download of 1500 images in train.
# ...

# %%
# !zip -r /content/Bear.zip /content/OID/Dataset_nl/train/Bear
# Out:
#   adding: content/OID/Dataset_nl/train/Bear/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Bear/b554e6b6baf7346d.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Bear/1e0795723de46f79.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bear/019d32b8b6837854.jpg (deflated 3%)
#   adding: content/OID/Dataset_nl/train/Bear/f6da553e11daf9da.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bear/88de695007db80c8.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bear/8b1dbcd222b20f36.jpg (deflated 7%)
#   adding: content/OID/Dataset_nl/train/Bear/5a985bc986439fd4.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Bear/00604a0bb35c3877.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bear/a5acd71b958139bb.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bear/559ae825bce5d349.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Bear/00e32ed9219749a7.jpg (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/Bear.zip")

# %%
# !zip -r /content/Person.zip /content/OID/Dataset_nl/train/Person
# Out:
#   adding: content/OID/Dataset_nl/train/Person/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Person/05078b840ef8813f.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/55cba24775a8b00a.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/e629eeb3b078c512.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/ed7b03d9e255521a.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/e8d9a049ee0241e0.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/7e8ee2ac0ae19040.jpg (deflated 4%)
#   adding: content/OID/Dataset_nl/train/Person/110b3ab39553269e.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Person/b780823b65e91e5f.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/4359a74a5ac4858c.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Person/7e1dee2938001109.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Person/5aaecc00236f078c.jpg (deflated 0%)
# ...

# %%
files.download('/content/Person.zip')

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Tree --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Tree
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 608662 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 3000 images in train.
# ...

# %%
# !cp /content/Person.zip /content/drive/MyDrive

# %%
# !cp /content/Bear.zip /content/drive/MyDrive

# %%
# !zip -r /content/Tree.zip /content/OID/Dataset_nl/train/Tree
# Out:
#   adding: content/OID/Dataset_nl/train/Tree/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Tree/af577c383ff50815.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/07fd65c30c48c061.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/f8893e4d604f4b2b.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/215c655839b65438.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Tree/b38a299b1cc3773d.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Tree/90242746ebd8aade.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/3558d0c1059c3a24.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/b9229999ac918b81.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/88468a31b9727008.jpg (deflated 2%)
#   adding: content/OID/Dataset_nl/train/Tree/c00fb11367f0a76d.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tree/590982c436ab8f14.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Tree.zip /content/drive/MyDrive

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Vehicle --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Vehicle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 447460 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 3000 images in train.
# ...

# %%
# !zip -r /content/Vehicle.zip /content/OID/Dataset_nl/train/Vehicle
# Out:
#   adding: content/OID/Dataset_nl/train/Vehicle/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/7303f7c4339d7070.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/b22c8f036c227537.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/1a592ca17db40b09.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/c99f125997d973a8.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/0b717a7c5520165c.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/fd48329e28679864.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Vehicle/87b6a46854671afb.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/7448ec7379becacc.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/8f8edf65435d129f.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/3a192ddb0da4a0ae.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Vehicle/f4b169c81d58dec1.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Vehicle.zip /content/drive/MyDrive

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Dog --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Dog
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 159243 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 3000 images in train.
# ...

# %%
# !zip -r /content/Dog.zip /content/OID/Dataset_nl/train/Dog
# Out:
#   adding: content/OID/Dataset_nl/train/Dog/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Dog/114273e85d452833.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/f9ba3802f57dbd2c.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/98dc6901a1b1c038.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/5458504fc3970ece.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/c57cecfe0f819e85.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/6c8a835054120f60.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/0bf6e7761defb965.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/a6c243c4f86d347c.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/8cd3842f7b891c3c.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/e072e086ada60fa2.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Dog/7ca4b90c5c53d78e.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Dog.zip /content/drive/MyDrive

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Bird --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Bird
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 152346 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 3000 images in train.
# ...

# %%
# !zip -r /content/Bird.zip /content/OID/Dataset_nl/train/Bird
# Out:
#   adding: content/OID/Dataset_nl/train/Bird/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Bird/427b528d3025466e.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/57cb66e8fb841b9a.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/b707489a51cfbbe2.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/354bf21db83ef9b4.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/ebd60718d675d338.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Bird/9bf0808927b4c228.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/d64a3cd8b73f2014.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Bird/cf6ef31372f681c6.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/7907478cb287d733.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/cf297cc80748cf48.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Bird/ed224f2838899bc2.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Bird.zip /content/drive/MyDrive

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Cat --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Cat
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 86048 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 3000 images in train.
# ...

# %%
# !zip -r /content/Cat.zip /content/OID/Dataset_nl/train/Cat
# Out:
#   adding: content/OID/Dataset_nl/train/Cat/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Cat/42b3b7c867d95fab.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/e3d325a5035d8214.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/eab1f24c7012000f.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Cat/d7f0a60b85d3b49d.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/cc6b56129cbbce03.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/e8678df62985305a.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/6d35fbb9c624afe0.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/7db18fff1aefebda.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/9b9c384c7505fbf3.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/e214eaabef8064a1.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Cat/01a842da936f8d2d.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Cat.zip /content/drive/MyDrive

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader_ill --sub h --classes Tiger --type_csv train --limit 3000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#
#      _____                      _                 _             _____ _      _
#     |  __ \                    | |               | |           |_   _| |    | |
#     | |  | | _____      ___ __ | | ___   __ _  __| | ___ _ __    | | | |    | |
#     | |  | |/ _ \ \ /\ / / '_ \| |/ _ \ / _` |/ _` |/ _ \ '__|   | | | |    | |
#     | |__| | (_) \ V  V /| | | | | (_) | (_| | (_| |  __/ |     _| |_| |____| |____
#     |_____/ \___/ \_/\_/ |_| |_|_|\___/ \__,_|\__,_|\___|_|    |_____|______|______|
#
#
#
#
# Tiger
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1826 online images for train.
#     [INFO] | Limiting to 3000 images.
#     [INFO] | Download of 1826 images in train.
# ...

# %%
# !zip -r /content/Tiger.zip /content/OID/Dataset_nl/train/Tiger
# Out:
#   adding: content/OID/Dataset_nl/train/Tiger/ (stored 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/50428ab76f1b6bbb.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/f31ed2575190d1ec.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/296f53daf6526815.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/53b601fdcf8053de.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/0bc64439b1ad5f1b.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/01afee909d184eae.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/001e14d493f00627.jpg (deflated 1%)
#   adding: content/OID/Dataset_nl/train/Tiger/00eb830f6b216e4c.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/7c387756bbad59b6.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/00441570a1aa8676.jpg (deflated 0%)
#   adding: content/OID/Dataset_nl/train/Tiger/850e97f8eef9bfc1.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Tiger.zip /content/drive/MyDrive

# %% [markdown]
# Object Detection Dataset

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader --classes Bear Person Elephant Tree Tiger --type_csv train --limit 400
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Bear.
#
# Bear
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 353 online images for train.
#     [INFO] | Limiting to 400 images.
#     [INFO] | Download of 353 images in train.
# 100% 353/353 [03:41<00:00,  1.59it/s]
#     [INFO] | Done!
# ...

# %%
# !zip -r /content/Tiger_od.zip /content/OID/Dataset/train/Tiger
# Out:
#   adding: content/OID/Dataset/train/Tiger/ (stored 0%)
#   adding: content/OID/Dataset/train/Tiger/24f1494420978e2f.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/09ce6386e7983989.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Tiger/b6eb7e90fb09e2e1.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/0e2b99b6e0d0a107.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/1651f3135f0ff9da.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/39eb513ec3001d1a.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/37b292b2a9d7dd6c.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/1e13ddd6c977fff8.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/f836b28773a8d436.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/e707f013e53421b2.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tiger/31a25f6f00f1ac67.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Tiger_od.zip /content/drive/MyDrive

# %%
# !zip -r /content/Elephant_od.zip /content/OID/Dataset/train/Elephant
# Out:
#   adding: content/OID/Dataset/train/Elephant/ (stored 0%)
#   adding: content/OID/Dataset/train/Elephant/dd867321cb03153f.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/08a17f4678786480.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/9626dc310fc8b63d.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/efeb678bf2de482f.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/b0552ea8e5459f37.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/0c74da0b19be6d65.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/b070df32b5def076.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/c3a1408dcde5a6b9.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/796ed78c792208af.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Elephant/de4bb330e26edf76.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Elephant/a0cd3d5695eb0110.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Elephant_od.zip /content/drive/MyDrive

# %%
# !zip -r /content/Tree_od.zip /content/OID/Dataset/train/Tree
# Out:
#   adding: content/OID/Dataset/train/Tree/ (stored 0%)
#   adding: content/OID/Dataset/train/Tree/069b8ca11c6b9d59.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/3ece4a18669cdd60.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/2f1cead90ca5e1ce.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/b788dd5305c7c196.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/adafecdc60b4ccb6.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/4422f60894cf605a.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/46ce8fdb260f7cda.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/fbb4bb4cfa26dd39.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/aa94f450822a9848.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/1eecc002cd9357f2.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/b0490c58707b7308.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Tree/b23bdf2c9a76049c.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Tree_od.zip /content/drive/MyDrive

# %%
# !zip -r /content/Person_od.zip /content/OID/Dataset/train/Person
# Out:
#   adding: content/OID/Dataset/train/Person/ (stored 0%)
#   adding: content/OID/Dataset/train/Person/5a58f524186789cf.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/d1a5dd7379e6dda0.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Person/c598073e54f0fac3.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/04da411bd4b23897.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/d14bd942cb5c4794.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Person/62110a074e669f91.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/862a351a4732742a.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/33f9a6d12e241848.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/ae87116b4d104c47.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/c8e3c26328c89333.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/85e944cb3a5a3c6a.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Person_od.zip /content/drive/MyDrive

# %%
# !zip -r /content/Bear_od.zip /content/OID/Dataset/train/Bear
# Out:
#   adding: content/OID/Dataset/train/Bear/ (stored 0%)
#   adding: content/OID/Dataset/train/Bear/032d3a7144b8e1b9.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/76fe7d2e63e08545.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/89bd58bf8854586e.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/0202a7d4caaed389.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/0a85e62973f2bcf6.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/30417fbad2cbb4f0.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/5c93d4fea8041e49.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/13e65684c1644d8d.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/8bf54049e196b535.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/f4b2b52ae19d4737.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/8651bf53521f2efe.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Bear/a6188fab6beea779.jpg (deflated 0%)
# ...

# %%
# !cp -r /content/Bear_od.zip /content/drive/MyDrive
